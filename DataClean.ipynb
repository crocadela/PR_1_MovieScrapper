# %% [markdown]
# Importamos las librerías necesarias

# %%
import pandas as pd
import json

# %%
with open('source/data_wiki.json', 'r') as f:   ## Cargamos el fichero json output del spyder
    data = json.load(f)
    print("Número de registros contenidos en el fichero json: {}".format(len(data)))
# Out:
# Número de registros contenidos en el fichero json: 5949

# %%
moviesData = []
moviesMetadata = []
castData = []

# iteramos sobre los datos y separamos la información en tres tablas principales:

for e,i in enumerate(data):
    keys = list(data[e].keys())
    if 'title' in keys:
        moviesData.append(data[e])
        #data.pop(e)
    elif 'movie' in keys:
        moviesMetadata.append(data[e])
    elif 'name' in keys:
        castData.append(data[e])

# %%
### Guardamos la información en los diferentes ficheros CSV. 

df_movies = pd.DataFrame(moviesData)
df_movies.to_csv("dataset/df_movies.csv",sep = "|", index=False)
print("Total Registros de películas: {}".format(df_movies.shape[0]))


df_metamovies = pd.DataFrame(moviesMetadata)
df_metamovies.to_csv("dataset/df_metamovies.csv",sep = "|", index=False)
print("Total Registros de información extra de las películas: {}".format(df_metamovies.shape[0]))

df_castData = pd.DataFrame(castData)
df_castData.to_csv("dataset/df_castData.csv",sep = "|", index=False)
print("Total Registros del cast de las películas: {}".format(df_castData.shape[0]))
# Out:
# Total Registros de películas: 1348
# Total Registros de información extra de las películas: 1346
# Total Registros del cast de las películas: 3255

# %%
df_movies.sample(3)
# Out:
#                     title  year  best movie awards nominations  \
# 1229   Spawn of the North  1938       False  0 (1)         0\n
# 1212  Since You Went Away  1944       False      1         9\n
# 1220     Some Like It Hot  1959       False      1         6\n
#
#                       linkMovie
# 1229   /wiki/Spawn_of_the_North
# 1212  /wiki/Since_You_Went_Away
# 1220     /wiki/Some_Like_It_Hot

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1348 entries, 0 to 1347
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        1347 non-null   object
#  1   year         1346 non-null   object
#  2   best movie   1348 non-null   bool
#  3   awards       1347 non-null   object
#  4   nominations  1347 non-null   object
#  5   linkMovie    1348 non-null   object
# dtypes: bool(1), object(5)
# memory usage: 54.1+ KB

# %%
df_metamovies.sample(3)
# Out:
#              movie                                               link  \
# 377   The Fugitive  https://en.wikipedia.org/wiki/The_Fugitive_(19...
# 1342  The Yearling  https://en.wikipedia.org/wiki/The_Yearling_(19...
# 198      The Queen  https://en.wikipedia.org/wiki/The_Queen_(2006_...
#
#       documentary          Directed                 Screenplay  \
# 377         False    [Andrew Davis]  [Jeb Stuart, David Twohy]
# 1342        False  [Clarence Brown]              [Paul Osborn]
# 198         False  [Stephen Frears]                         []
#
#                                                Starring  \
# 377   [Harrison Ford, Tommy Lee Jones, Sela Ward, Jo...
# 1342                                     [Gregory Peck]
# 198   [Helen Mirren, Michael Sheen, James Cromwell, ...
#
#                                               Produced     Cinematography  \
# 377                                  [Arnold Kopelson]  [Michael Chapman]
# 1342                                 [Sidney Franklin]    [Arthur Arling]
# 198   [Andy Harries, Christine Langan, Tracey Seaward]    [Affonso Beato]
#
#                                                  Edited  \
# 377   [Don Brochu, David Finfer, Dean Goodhill, Dov ...
# 1342                                  [Harold F. Kress]
# 198                                   [Lucia Zucchetti]
#
#                       Music  \
# 377   [James Newton Howard]
# 1342     [Herbert Stothart]
# 198     [Alexandre Desplat]
#
#                                              Production  \
# 377                            [Kopelson Entertainment]
# 1342                              [Metro-Goldwyn-Mayer]
# 198   [Pathé Renn Production, Granada Productions, B...
#
#                                             Distributed  \
# 377                                      [Warner Bros.]
# 1342                                     [Loew's, Inc.]
# 198   [Pathé Distribution (United Kingdom, France an...
#
#                                            Release date   Running time  \
# 377                     [July 29, 1993, August 6, 1993]  [130 minutes]
# 1342                                [December 18, 1946]  [128 minutes]
# 198   [2 September 2006, 15 September 2006, 18 Octob...  [103 minutes]
#
#                                Countr   Language         Budget  \
# 377                   [United States]  [English]  [$44 million]
# 1342                  [United States]  [English]   [$3,883,000]
# 198   [United Kingdom, France, Italy]  [English]  [$15 million]
#
#             Box office
# 377   [$368.9 million]
# 1342      [$7,599,000]
# 198   [$123.5 million]

# %%
df_castData.sample(3)
# Out:
#                    name female   birthdate                    birthplace  \
# 1613  Maximilian Schell  False  1930-12-08         [Vienna, , , Austria]
# 1178        Kathy Burke   True  1964-06-13           [London, , England]
# 448       Til Schweiger  False  1963-12-19  [Freiburg, , , West Germany]
#
#                                                  link
# 1613  https://en.wikipedia.org/wiki/Maximilian_Schell
# 1178        https://en.wikipedia.org/wiki/Kathy_Burke
# 448       https://en.wikipedia.org/wiki/Til_Schweiger
